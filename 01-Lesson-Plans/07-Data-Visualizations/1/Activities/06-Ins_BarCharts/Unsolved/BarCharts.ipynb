# %%
# %matplotlib widget

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create an array that contains the number of users each language has
users = [13000, 26000, 52000, 30000, 9000]
x_axis = np.arange(len(users))

# %%
# Tell matplotlib that we will be making a bar chart
# Users is our y axis and x_axis is, of course, our x axis
# We apply align="center" to ensure our bars line up with our tick marks
# Out:
# <BarContainer object of 5 artists>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# <!--
# ![Output chart](https://static.bc-edx.com/ai/ail-v-1-0/m7/lesson_1/img/06-figure-step-1.png)
# -->

# %%
# Tell matplotlib where we would like to place each of our x axis headers
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# <!--
# ![Output chart](https://static.bc-edx.com/ai/ail-v-1-0/m7/lesson_1/img/06-figure-step-2.png)
# -->

# %%
# Sets the x limits of the current chart
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# <!--
# ![Output chart](https://static.bc-edx.com/ai/ail-v-1-0/m7/lesson_1/img/06-figure-step-3.png)
# -->

# %%
# Sets the y limits of the current chart
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# <!--
# ![Output chart](https://static.bc-edx.com/ai/ail-v-1-0/m7/lesson_1/img/06-figure-step-4.png)
# -->

# %%
# Give our chart some labels and a tile
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# <!--
# ![Output chart](https://static.bc-edx.com/ai/ail-v-1-0/m7/lesson_1/img/06-figure-step-5.png)
# -->
