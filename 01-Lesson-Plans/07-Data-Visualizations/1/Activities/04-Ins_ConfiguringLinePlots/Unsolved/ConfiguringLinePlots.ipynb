# %% [markdown]
# # Configuring Line Plots

# %%
# %matplotlib widget

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Customizing the Sinusoidal Graph

# %%
# Generate the x values from 0 to 10 using a step of 0.1

# %% [markdown]
# ### Data Markers

# %%
# Use dots or other markers for your plots, and change their colors
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# <!--
# ![Output chart](https://static.bc-edx.com/ai/ail-v-1-0/m7/lesson_1/img/04-figure-step-1.png)
# -->

# %% [markdown]
# ### Reference Lines

# %%
# Add a semi-transparent horizontal line at y = 0

# %% [markdown]
# ### Axis Labels

# %%
# Add labels to the x and y axes
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# <!--
# ![Output chart](https://static.bc-edx.com/ai/ail-v-1-0/m7/lesson_1/img/04-figure-step-2.png)
# -->

# %% [markdown]
# ### Axis Limits

# %%
# Set your x and y limits
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# <!--
# ![Output chart](https://static.bc-edx.com/ai/ail-v-1-0/m7/lesson_1/img/04-figure-step-3.png)
# -->

# %% [markdown]
# ### Gridlines

# %%
# Set a grid on the plot
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# <!--
# ![Output chart](https://static.bc-edx.com/ai/ail-v-1-0/m7/lesson_1/img/04-figure-step-4.png)
# -->

# %% [markdown]
# ### Legend

# %%
# Adds a legend and sets its location to the lower right
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# <!--
# ![Output chart](https://static.bc-edx.com/ai/ail-v-1-0/m7/lesson_1/img/04-figure-step-5.png)
# -->

# %% [markdown]
# ### Saving Plots

# %%
# Save the plot and display it
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# <!--
# ![Output chart](https://static.bc-edx.com/ai/ail-v-1-0/m7/lesson_1/img/04-figure-step-6.png)
# -->
